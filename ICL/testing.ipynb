# %%
import data as d
import torch

# %%
torch.manual_seed(0)
data = d.make_batch_fixed_n_ctx(batch_size=1, n_ctx=32, d=3)
data[0]
# Out:
# tensor([[[-3.5613e-01,  4.3722e-01,  4.9131e-01, -1.7439e+00],
#          [-2.0410e-01, -8.8531e-02,  5.2388e-01, -1.3743e+00],
#          [-6.6587e-01,  8.5038e-01, -1.0438e+00,  1.0126e+00],
#          [-1.3453e+00,  7.8536e-01,  9.9284e-01, -4.4450e+00],
#          [-1.9318e-01, -3.0896e-01,  5.0257e-01, -1.3422e+00],
#          [-8.5945e-01,  4.6810e-01, -1.5771e-01, -1.1829e+00],
#          [ 1.4437e+00,  2.6605e-01,  1.6646e-01,  1.7464e+00],
#          [ 8.7438e-01, -1.4347e-01, -1.1161e-01,  1.5671e+00],
#          [ 9.3183e-01,  1.2590e+00,  2.0050e+00, -3.2916e+00],
#          [ 5.3737e-02,  6.1806e-01, -4.1280e-01,  7.8419e-01],
#          [-8.4106e-01, -2.3160e+00, -2.1586e-01, -1.6760e-01],
#          [-7.4255e-01,  5.6272e-01,  2.5963e-01, -1.8634e+00],
#          [-1.7396e-01, -6.7875e-01,  9.3826e-01, -2.0733e+00],
#          [ 4.8887e-01,  1.2032e+00,  8.4535e-02,  2.0686e-01],
#          [-1.2001e+00, -4.7859e-03, -5.1807e-01, -7.3774e-01],
# ...

# %%
# Out:
# tensor([-2.3496, -0.3028])
