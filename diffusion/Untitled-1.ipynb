# %%
# !ls
# Out:
# README.md          markov_chains      torch_linreg.ipynb
# diffusion          phi-1.ipynb        toy-data
# high-dim           stat527            transformer

# %%
from diffusion.my_diffusion import UNET
import torch

# %%
model = UNET()

# %%
print(model.state_dict())
# Out:
# OrderedDict([('conv_in_proj.weight', tensor([[[[-1.2998e-01, -1.9057e-01,  6.7067e-03],
#           [ 3.0245e-03,  1.2046e-02,  1.4931e-02],
#           [-8.0666e-02,  1.4108e-01,  1.2678e-01]],
#
#          [[ 9.6020e-02,  1.4811e-01, -1.0708e-01],
#           [ 1.5282e-01,  1.2403e-01, -1.9055e-02],
#           [-1.6394e-01, -7.5066e-03, -1.0915e-01]],
#
#          [[-1.1259e-01,  1.4843e-01,  1.7670e-01],
#           [ 5.7905e-03,  1.2380e-01, -8.1182e-03],
#           [-1.6584e-01,  4.0193e-02,  6.8796e-02]]],
#
#
#         [[[ 1.5891e-01, -1.2388e-01,  1.4043e-01],
#           [ 6.9501e-02, -1.1027e-01, -2.4542e-02],
#           [-4.9751e-02, -4.9970e-04,  1.0045e-01]],
#
#          [[ 4.9039e-02,  1.8440e-01, -1.1693e-01],
#           [-1.6819e-01,  1.5391e-01, -5.0879e-02],
#           [ 1.4998e-02, -1.4582e-01,  1.9132e-01]],
#
#          [[ 1.4308e-01, -1.2852e-01,  1.2058e-01],
#           [-1.5942e-01, -1.0041e-01, -5.6154e-02],
# ...

# %%
import torch

# %%
an = abs(torch.randn(20))

bn = torch.randn(20)

# %%
# Out:
# tensor([0.0212, 0.3602, 0.7947, 0.3228, 0.0399, 1.3712, 0.5113, 1.3062, 0.3101,
#         0.0495, 1.8205, 1.0434, 0.0041, 0.1553, 0.5834, 0.3801, 0.7258, 0.0039,
#         0.0069, 0.5219])

# %%
an * abs(bn) == abs(an * bn)
# Out:
# tensor([True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True])
